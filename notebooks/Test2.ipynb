# %%
# Setup Gemini model for QA
def gemini_generate_cover_letter(query):
    print("generate cover letter")
    API_KEY = 'AIzaSyCPnyyq5v-84aT4WpIdaWBYVoOehSRCIqw'
    genai.configure(api_key=API_KEY)
    model = genai.GenerativeModel("gemini-1.5-flash")
    # Build the prompt for Gemini
    prompt = f"""
    Write a professional cover letter based on the following query:
        
    {query}
    """
    response = model.generate_content(prompt)
    print(response)
    return response.text.strip()

# Define and run the query
query = 'Write a cover letter for the given CV and Job posting in a conversational style and include the writer’s name at the end.'
result = gemini_generate_cover_letter(query)
print("The result is",result)
return result
# Out:
# generate cover letter
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "Please provide me with the CV and the job posting so I can write a professional cover letter in a conversational style. I'll need the details of the position, the company, and your skills and experience to tailor the letter to your specific qualifications. \n\nOnce you share the documents, I'll get to work on a cover letter that will help you stand out from the crowd! \n"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0,
#           "safety_ratings": [
#             {
#               "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
# ...

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA
import os
import google.generativeai as genai
from langchain.embeddings import HuggingFaceEmbeddings
from pdf_reader import load_pdf
from read_job_posting import extract_text_from_url

from splitter import split_text_documents

# %%
from bs4 import BeautifulSoup
import requests

from splitter import text_to_doc_splitter

def extract_text_from_url(url):
    html = requests.get(url).text
    soup = BeautifulSoup(html, features="html.parser")
    text = []
    for lines in soup.findAll('div', {'class': 'description__text'}):
        text.append(lines.get_text())
    
    lines = (line.strip() for line in text)
    text = '\n'.join(line for line in lines if line)
    
    document = text_to_doc_splitter(text)

    return document
def get_cover_letter(url, pdf, gemini_api_key):
    print("Get Cover Letter")
    # Load and process the user's resume and job posting text
    genai.configure(api_key=gemini_api_key)
    pdf_doc = load_pdf(pdf)
    print(pdf_doc)
    job_post = extract_text_from_url(url)
    print("\n\n",job_post,"\n\n")
    pdf_doc.extend(job_post)
    print(pdf_doc)
    documents = split_text_documents(pdf_doc)
    print(documents)
    print()
    print(1)
    # Generate embeddings using a model compatible with Chroma
    #embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")  # Replace with an appropriate model
    #vectordb = Chroma.from_documents(documents, embedding=embeddings)  # or use FAISS if Chroma unsupported
    print(2)
    # Setup Gemini model for QA
    def gemini_generate_cover_letter(query):
        print("generate cover letter")
        model = genai.GenerativeModel("gemini-1.5-flash")
        # Build the prompt for Gemini
        prompt = f"""
        Write a professional cover letter based on the following query:
        
        {documents}
        """
        response = model.generate_content(prompt)
        print(response)
        return response.text.strip()

    # Define and run the query
    query = 'Write a cover letter for the given CV and Job posting in a conversational style and include the writer’s name at the end.'
    result = gemini_generate_cover_letter(query)
    print(result)
    return result

# %%
get_cover_letter('https://www.linkedin.com/jobs/view/4004214114/','Akshay Kumar Resume.pdf','AIzaSyCPnyyq5v-84aT4WpIdaWBYVoOehSRCIqw')
# Out:
# Get Cover Letter
# ...

# %%
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.chat_models import ChatOpenAI
import os
from pdf_reader import load_pdf
from read_job_posting import extract_text_from_url
import google.generativeai as genai
from langchain.embeddings import HuggingFaceEmbeddings


import requests

def get_cover_letter(url, pdf, instructions, gemini_api_key):
    print("Get Cover Letter")
    
    # Load and process the user's resume and job posting text
    genai.configure(api_key=gemini_api_key)
    pdf_doc = load_pdf(pdf)
    
    # Check if the URL is accessible or treat it as plain text
    job_post = ""
    try:
        print("Trying to get job info")
        response = requests.get(url)
        if response.status_code == 200:
            job_post = extract_text_from_url(url)  # Extract text from URL if accessible
            print("/n/n",job_post,"/n/n")
        else:
            raise Exception("URL not accessible")
    except Exception as e:
        print("Did not get job info")
        print(f"Error accessing URL: {e}. Treating URL as plain text.")
        job_post = url  # If URL is not accessible, treat it as plain text job description
    
    pdf_doc.extend(job_post)
    documents = pdf_doc
    
    # Setup Gemini model for QA
    def gemini_generate_cover_letter():
        print("Generate cover letter")
        model = genai.GenerativeModel("gemini-1.5-flash")
        prompt = f"""
        Write a professional cover letter based on the following information:
        
        {documents}        
        """
        if instructions:
            prompt += f"\nI have some special instructions for you: {instructions}"
        
        response = model.generate_content(prompt)
        print(response)
        return response.text.strip()

    # Define and run the query
    result = gemini_generate_cover_letter()
    print(result)
    return result

# %%
get_cover_letter('https://www.linkedin.com/jobs/view/4004214114/','Akshay Kumar Resume.pdf',"",'AIzaSyCPnyyq5v-84aT4WpIdaWBYVoOehSRCIqw')
# Out:
# Get Cover Letter
# Trying to get job info
# Did not get job info
# Error accessing URL: URL not accessible. Treating URL as plain text.
# Generate cover letter
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...
